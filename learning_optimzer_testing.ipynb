# %%
# %load_ext autoreload
# %autoreload 2

# %%
from experiment_runner import run_all_experiments

# %%
SEARCH_SPACE = {
    "model": ["smallcnn", "bigcnn"],

    "lr": [1e-3, 5e-4, 1e-4],

    "batch_size": [64, 128],

    "weight_decay": [0, 1e-4, 1e-3],

    "dropout": [0.3, 0.5]
}
run_all_experiments(SEARCH_SPACE)
# Out:
# Base hyperparameters: {'lr': 0.001, 'batch_size': 128, 'weight_decay': 0.0001, 'dropout': 0.5}
# Running model: smallcnn with config: {'lr': 0.001, 'batch_size': 128, 'weight_decay': 0.0001, 'dropout': 0.5, 'model': 'smallcnn'}
# Seed: 0
# Epoch 1 | train 1.7328 | val 1.4938
# Epoch 2 | train 1.4617 | val 1.3306
# Epoch 3 | train 1.3620 | val 1.2974
# Epoch 4 | train 1.2909 | val 1.2098
# Epoch 5 | train 1.2452 | val 1.2698
# Epoch 6 | train 1.1672 | val 1.0769
# Epoch 7 | train 1.1357 | val 1.0683
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#       1 SEARCH_SPACE = {
#       2     "model": ["smallcnn", "bigcnn"],
#       3
#    (...)     10     "dropout": [0.3, 0.5]
#      11 }
# ---> 12 run_all_experiments(SEARCH_SPACE)
#
# File ~/projects/convolutional-neural-networks/experiment_runner.py:63, in run_all_experiments(search_space, n_samples)
#      57     # Create a unique model checkpoint per experiment, model, and seed
#      58     model_path = os.path.join(
#      59         RESULTS_DIR,
#      60         f"best_model_exp{experiment_id}_{model_name}_seed{seed}.pth"
#      61     )
# ---> 63     result = run_single(config, seed, model_path=model_path)
#      64     results.append(result)
#      66 # Save JSON results
#
# File ~/projects/convolutional-neural-networks/experiment_runner.py:102, in run_single(config, seed, model_path)
#      90 optimizer = torch.optim.AdamW(
#      91     model.parameters(),
#      92     lr=config["lr"],
#      93     weight_decay=config["weight_decay"]
#      94 )
#      96 scheduler = torch.optim.lr_scheduler.StepLR(
#      97     optimizer,
#      98     step_size=5,
#      99     gamma=0.5
#     100 )
# --> 102 logs = train_model(
#     103     model,
#     104     train_loader,
#     105     val_loader,
#     106     optimizer,
#     107     scheduler,
#     108     EPOCHS,
#     109     device,
#     110     model_path=model_path  # pass path to training loop
#     111 )
#     113 # Load best model
#     114 model.load_state_dict(torch.load(model_path))
#
# File ~/projects/convolutional-neural-networks/train.py:60, in train_model(model, train_loader, val_loader, optimizer, scheduler, epochs, device, model_path)
#      57 train_loss_total += loss.item() * batch_size
#      58 n += batch_size
# ---> 60 scaler.scale(loss).backward()
#      61 scaler.step(optimizer)
#      62 scaler.update()
#
# File ~/projects/convolutional-neural-networks/venv/lib/python3.12/site-packages/torch/_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File ~/projects/convolutional-neural-networks/venv/lib/python3.12/site-packages/torch/autograd/__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File ~/projects/convolutional-neural-networks/venv/lib/python3.12/site-packages/torch/autograd/graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# KeyboardInterrupt:
