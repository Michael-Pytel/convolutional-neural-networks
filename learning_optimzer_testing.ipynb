# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import experiment_runner

# %%
SEARCH_SPACE = {
    "model": ["smallcnn", "bigcnn"],

    "lr": [1e-3, 5e-4, 1e-4],

    "batch_size": [64, 128],

    "weight_decay": [0, 1e-4, 1e-3],

    "dropout": [0.3, 0.5]
}
experiment_runner.run_all_experiments(SEARCH_SPACE)
# Out:
# Base hyperparameters: {'lr': 0.001, 'batch_size': 128, 'weight_decay': 0.0001, 'dropout': 0.5}
# Running model: smallcnn with config: {'lr': 0.001, 'batch_size': 128, 'weight_decay': 0.0001, 'dropout': 0.5, 'model': 'smallcnn'}
# Seed: 0
# Epoch 1 | train 1.7328 | val 1.4938
# Epoch 2 | train 1.4664 | val 1.3015
# Epoch 3 | train 1.3597 | val 1.2432
# Epoch 4 | train 1.2934 | val 1.1984
# Epoch 5 | train 1.2379 | val 1.1580
# Epoch 6 | train 1.1983 | val 1.1035
# Epoch 7 | train 1.1654 | val 1.1574
# Epoch 8 | train 1.1358 | val 1.0797
# Epoch 9 | train 1.1040 | val 1.0525
# Epoch 10 | train 1.0787 | val 1.0505
# Epoch 11 | train 1.0515 | val 1.0268
# Epoch 12 | train 1.0290 | val 1.0155
# Epoch 13 | train 1.0051 | val 1.0146
# Epoch 14 | train 0.9815 | val 1.0124
# Epoch 15 | train 0.9646 | val 1.0118
# Epoch 16 | train 0.9474 | val 1.0095
# Epoch 17 | train 0.9307 | val 1.0040
# Epoch 18 | train 0.9234 | val 1.0053
# Epoch 19 | train 0.9125 | val 1.0052
# ...
